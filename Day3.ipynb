# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotirmaya2004/NIELIT-Internship/blob/main/Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Control flow

# %% [markdown]
# #### A program's control flow is the order in which the program's code executes.
# #### The control flow of a python program is regualted by conditional statements, loops and function calls.
# #### python has three types of control structures:
# ##### 1.Sequential : default mode
# ##### 2.Selection : used for decisions and branching
# ##### 3.Repetition : used for looping,i.e. reporting a piece of code in multiple times

# %% [markdown]
# ##if else

# %%
age =18
if age>=18:
  print("You are eligible to vote")
else:
  print("You are not eligible to vote")
# Out:
# You are eligible to vote

# %%
age=int(input("Enter your age : "))
if age>=18:
  print("You are eligible to vote")
else:
  print("You are not eligible to vote")
# Out:
# Enter your age : 23
# You are eligible to vote

# %% [markdown]
# ##Nested If else

# %%
num= int(input("Enter a Number : "))
if num>0:
  print("Positive number")
  if num%2==0:
    print("Even number")
  else:
    print("Odd number")
else:
  print("Negative number")
# Out:
# Enter a Number : 43
# Positive number
# Odd number

# %% [markdown]
# ## If elif else

# %%
marks = int(input("Enter your marks : "))
if marks >= 90 :
  print("Grade A")
  print("Excellent Performance")
elif marks >= 70 :
  print("Grade B")
  print("Very Good Performance")
elif marks >= 50:
  print("Grade C")
  print("Good Performance")
else :
  print("Fail")
# Out:
# Enter your marks : 67
# Grade C
# Good Performance

# %% [markdown]
# ## Repetition

# %% [markdown]
# #### A repetition statement is used to repeat a group(block) of programming instructions.
# #### In python,we generally have two loops/repetitive stastements:
# ##### 1. for loop
# ##### 2. while loop

# %% [markdown]
# ### For Loop

# %%
for i in range(0,6,1):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in "Hello":
  print(i)
# Out:
# H
# e
# l
# l
# o

# %% [markdown]
# ### While loop

# %%
i=1
while i<=5:
  print(i)
  i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#sum of digit
num=int(input("Enter a number : "))
sum=0
# Loop while the number is greater than 0
while num > 0:
  dg=num % 10
  sum+=dg
  # Use integer division to remove the last digit
  num //= 10
print("Sum : ",sum)
# Out:
# Enter a number : 23
# Sum :  5
