# %% [markdown]
# ## AI

# %% [markdown]
# AI is the science of making machines do things that would require intellligence if done by men. Marvin Minsky

# %% [markdown]
# #### Scope of AI

# %% [markdown]
# 1. machine Learning

# %% [markdown]
# 2. Natural Language processing(NLP)

# %% [markdown]
# 3. Computer vision

# %% [markdown]
# 4. Robotics

# %% [markdown]
# 5. Expert Systems

# %% [markdown]
# 6. Generative AI

# %% [markdown]
# Ai intersects with mathematics, statistics, neuroscience, linguistic, and software engineering

# %% [markdown]
# ### Importance of AI in modern world

# %% [markdown]
# AI is no longer experimental it powers the global economy and critical infrastructure:
# 1. Drives innovation in healthcare, finance, education and defense
# 2. Enbles automation of repetitive and high risk tasks
# 3. Processes data at a scale impossible for humans
# 4. Powers personalized experiences at billions of touchpoints daily
# 5. Estimated to add $15.7 trillion to the global economy by 2030(PwC).

# %% [markdown]
# nations and companies that lead in AI will lead the future

# %% [markdown]
# ### Everyday impact of AI

# %% [markdown]
# 1. Voice assistances like Alexa and Google Assistant.
# 2. Reccommendation systems in Netflix, Youtube and Amazon
# 3. Face recognition in smartphones
# 4. Spam filtering in emails.
# 5. Navigation apps like Google maps providing real-time traffic updates.

# %% [markdown]
# ### Evolution of AI

# %% [markdown]
# #### Early AI(Rule based systems)

# %% [markdown]
# The first AI systems did not learn they followed strict rules written by humans
# 1. Prograns wre built
