# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotirmaya2004/NIELIT-Internship/blob/main/Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## break

# %% [markdown]
# #### In general, there arises so many situations when a loop is to be terminated on reaching a particular external condition and in such state Python break’ statement is used. Thus, the ‘break’ statement is used to come out of the currently running loop upon reaching the desired condition.

# %% [markdown]
# ####Syntax:
#
#
# ```
# for i in range(1,10):
#   condition
#   break;
# ```

# %%
#using while statement
i=1
while(i<=10):
  print(i)
  if(i==5):
    break
  i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#using while statement
i=1
for i in range(1,10):
  print(i)
  if(i==5):
    break
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## continue

# %% [markdown]
# #### In case of the Python continue statement next iteration of the loop takes place while ignoring the statements after the continue statement i.e. continue statement makes the control jumps back at the start of the loop for iterating again according the set condition for the entry into the loop.

# %%
i=0
sub="Python"
while(i<len(sub)):
  if(sub[i]=="o" or sub[i]=='y'):
    i=i+1
    continue
  print(sub[i])
  i=i+1
print("End of Program")
# Out:
# P
# t
# h
# n
# End of Program

# %% [markdown]
# ## pass

# %% [markdown]
# #### Python pass statement is used when a condition is required to make the code complete but the statements attached with it are not required to be executed.
# #### Syntax:
# ```
# If(condition):
#   pass
#
# ```

# %%
marks =int(input("Enter the marks : "))
if(marks>50):
  print("Great")
elif(marks==50):
  pass
else:
  print("Do hard work")
# Out:
# Enter the marks : 34
# Do hard work

# %%
for i in "Python":
  if i=="o" or i=="y":
    continue
  print(i)
print("End of Program")
# Out:
# P
# t
# h
# n
# End of Program

# %% [markdown]
# ## assert

# %% [markdown]
# #### In Python assert statement is used to check the whether a condition or a logical expression is true or false.  The assert statement is very useful in tracking the errors and terminating the program on occurrence of an error.
# #### Syntax:
# ```assert (condtion)```

# %%
password=input("Enter the password : ")
assert password=="Python"
print("Number Entered : ",password)
# Out:
# Enter the password : abc
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_12023/2171125380.py in <cell line: 0>()
#       1 password=input("Enter the password : ")
# ----> 2 assert password=="Python"
#       3 print("Number Entered : ",password)
#
# AssertionError:

# %% [markdown]
# ### assertion error
# ####In above example, in case the user enters any other password than ‘PYTHON’ the error message occurs and program is not executed further.

# %%
password=input("Enter the password : ")
assert password=="Python"
print("Number Entered : ",password)
# Out:
# Enter the password : Python
# Number Entered :  Python

# %% [markdown]
# ## String handling and Sequenece Types

# %% [markdown]
# ### String Handling

# %% [markdown]
# ##### A string is a series of characters. In Python, anything inside quotes is a string. And you can use either single or double quotes. It is just like an array in C language and they are stored and accessed using index.

# %% [markdown]
# #### **Indexing**

# %%
str1="Hello"
print(str1[0])
print(str1[-1])
# Out:
# H
# o

# %% [markdown]
# #### **Slicing**

# %% [markdown]
# #### **Slicing**
# #### **arr[start:stop]**
# * ##### items start through stop-1
# #### **arr[start:]**
# * ##### items start through the rest of the array
# #### **arr[:stop]**
# * ##### items from the beginning through stop-1
# #### **arr[:]**
# * ##### a copy of the whole array
# #### **arr[start:stop:step]**
# * ##### start through not past stop, by step

# %%
mystring="hello"
print(mystring[1:4])
print(mystring[1:])
print(mystring[:])
# Out:
# ell
# ello
# hello

# %% [markdown]
# #### **Traversing a String**

# %%
mystr="Hello"
n=len(mystr)
for i in range(0,n):
  print(mystr[i])
# Out:
# H
# e
# l
# l
# o

# %% [markdown]
# #### **Concatenation of String**
# ##### The ‘+’ operator works differently with string and perform concatenation means it joins two or more strings to form a single string.

# %%
str1="Hello"
str2="World"
str3=str1+str2
print(str3)
# Out:
# HelloWorld

# %% [markdown]
# #### Replication operator(*)

# %% [markdown]
# ##### There may be times when you need to use Python to automate tasks, and one way you may do this is through repeating a string several times. You can do so with the ‘*’ operator. Like the ‘+’ operator, the ‘*’ operator has a different use when used with numbers, where it is the operator for multiplication. When used with one string and one integer, ‘*’ is the string replication operator, repeating a single string however many times you would like through the integer you provide.

# %%
str1="Hello"
str2=str1*3
print(str2)
# Out:
# HelloHelloHello

# %% [markdown]
# #### Membership Operator

# %%
mystr="hello"
print("h" in mystr)
# Out:
# True

# %% [markdown]
# #### **Comparision Operator**

# %% [markdown]
# | Operator | Description |
# |---|---|
# | ‘==’ | This checks whether two strings are equal |
# | ‘!=’ | This checks if two strings are not equal |
# | ‘<’ | This checks if the string on its left is smaller than that on its right |
# | ‘<=’ | This checks if the string on its left is smaller than or equal to that on its right |
# | ‘>’ | This checks if the string on its left is greater than that on its right |
# | ‘>=’ | This checks if the string on its left is greater than or equal to that on its right |

# %%
result=("schooldays"=="school days")
print(result)
# Out:
# False

# %%
result=("schooldays"=="schooldays")
print(result)
# Out:
# True

# %%
result=("school">"SCHOOL")
print(result)
# Out:
# True

# %%
result=("schooldays"!="school days")
print(result)
# Out:
# True

# %% [markdown]
# | Feature | List | Tuple | String  |
# | --- | --- |--- |--- |
# | **** ||||
# | **** ||||
# | **** ||||
# | **** ||||
# | **** ||||
# | **** ||||
# | **** ||||
